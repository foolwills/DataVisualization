# %%
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

print("✅ Kaggle API 配置成功！")
# Out:
# ✅ Kaggle API 配置成功！

# %%
api.dataset_download_files('olistbr/brazilian-ecommerce', path='./data', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce

# %%
import duckdb

# 连接数据库
con = duckdb.connect("ecommerce.duckdb")

# 创建表并导入CSV
con.execute("""
CREATE TABLE orders AS
SELECT * FROM read_csv_auto('data/olist/olist_customers_dataset.csv')
""")
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[13], line 7
#       4 con = duckdb.connect("ecommerce.duckdb")
#       6 # 创建表并导入CSV
# ----> 7 con.execute("""
#       8 CREATE TABLE orders AS
#       9 SELECT * FROM read_csv_auto('data/olist/olist_customers_dataset.csv')
#      10 """)
#      12 print(con.execute("SELECT * FROM orders LIMIT 5").fetchall())
#
# CatalogException: Catalog Error: Table with name "orders" already exists!

# %%
print(con.execute("SELECT * FROM orders LIMIT 5").fetchall())
# Out:
# [('06b8999e2fba1a1fbc88172c00ba8bc7', '861eff4711a542e4b93843c6dd7febb0', '14409', 'franca', 'SP'), ('18955e83d337fd6b2def6b18a428ac77', '290c77bc529b7ac935b93aa66c333dc3', '09790', 'sao bernardo do campo', 'SP'), ('4e7b3e00288586ebd08712fdd0374a03', '060e732b5b29e8181a18229c7b0b2b5e', '01151', 'sao paulo', 'SP'), ('b2b6027bc5c5109e529d4dc6358b12c3', '259dac757896d24d7702b9acbbff3f3c', '08775', 'mogi das cruzes', 'SP'), ('4f2d8ab171c80ec8364f7c12e35b23ad', '345ecd01c38d18a9036ed96c73b8d066', '13056', 'campinas', 'SP')]
